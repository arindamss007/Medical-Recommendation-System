# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/medical data.csv')

df
# Out:
#             Name DateOfBirth  Gender                    Symptoms  \
# 0       John Doe  15-05-1980    Male                Fever, Cough
# 1     Jane Smith  10-08-1992  Female           Headache, Fatigue
# 2    Michael Lee  20-02-1975    Male         Shortness of breath
# 3     Emily Chen  03-11-1988  Female            Nausea, Vomiting
# 4      Alex Wong  12-06-2001    Male                 Sore Throat
# ..           ...         ...     ...                         ...
# 282      Ava Lim  11-07-1993  Female  Cough, Shortness of breath
# 283     Liam Goh  16-09-1987    Male            Itching, Redness
# 284   Sophie Tan  18-02-1975  Female        Muscle Pain, Fatigue
# 285     Noah Lim  21-05-2005    Male            Nausea, Vomiting
# 286    Ella Wong  05-10-1999  Female    Headache, Blurred Vision
#
#                    Causes               Disease               Medicine
# 0         Viral Infection           Common Cold        Ibuprofen, Rest
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#             Name DateOfBirth  Gender                    Symptoms  \
# 0       John Doe  15-05-1980    Male                Fever, Cough
# 1     Jane Smith  10-08-1992  Female           Headache, Fatigue
# 2    Michael Lee  20-02-1975    Male         Shortness of breath
# 3     Emily Chen  03-11-1988  Female            Nausea, Vomiting
# 4      Alex Wong  12-06-2001    Male                 Sore Throat
# ..           ...         ...     ...                         ...
# 282      Ava Lim  11-07-1993  Female  Cough, Shortness of breath
# 283     Liam Goh  16-09-1987    Male            Itching, Redness
# 284   Sophie Tan  18-02-1975  Female        Muscle Pain, Fatigue
# 285     Noah Lim  21-05-2005    Male            Nausea, Vomiting
# 286    Ella Wong  05-10-1999  Female    Headache, Blurred Vision
#
#                    Causes               Disease               Medicine
# 0         Viral Infection           Common Cold        Ibuprofen, Rest
# ...

# %%
sns.countplot(x=df['Gender'])
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
count = df['Causes'].value_counts()
count_df = pd.DataFrame(count)
count_df
# Out:
#                           Causes
# Food Poisoning                20
# Viral Infection               17
# Allergies                     15
# Stress                        15
# Chronic Fatigue Syndrome      13
# ...                          ...
# Pregnancy                      1
# Herniated Disc                 1
# Autoimmune Response            1
# Spicy Food                     1
# Eye Strain                     1
#
# [61 rows x 1 columns]

# %%
count = df['Medicine'].value_counts()
count_df = pd.DataFrame(count)
count_df
# Out:
#                    Medicine
# Rest, Lifestyle          16
# NSAIDs                   15
# Antibiotics, Rest        12
# Oral Rehydration         10
# Fluids, Rest             10
# ...                     ...
#  Hydration, Rest          1
# Acetaminophen             1
# Honey, Rest               1
#  Sertraline               1
# Eye Exercises             1
#
# [64 rows x 1 columns]

# %%
count = df['Symptoms'].value_counts()
count_df = pd.DataFrame(count)
count_df
# Out:
#                                  Symptoms
# Fatigue, Weakness                      19
# Fever, Chills                          13
# Nausea, Dizziness                      11
# Nausea, Vomiting                       11
# Headache, Blurred Vision               11
# Fever, Sore Throat                     10
# Muscle Pain, Fatigue                   10
# Stomach Pain, Diarrhea                 10
# Itching, Redness                       10
# Joint Pain, Swelling                    9
# Chest Pain, Shortness of breath         9
# Shortness of breath                     8
# Back Pain, Numbness                     8
# Abdominal Pain, Bloating                7
# Joint Pain, Fatigue                     7
# Anxiety, Palpitations                   7
# Headache, Sensitivity                   5
# Dizziness, Fatigue                      5
# Cough, Fever                            5
# Nausea, Cramps                          5
# Chest Pain, Shortness                   5
# ...

# %%
df.isnull().sum()
# Out:
# Name           0
# DateOfBirth    0
# Gender         0
# Symptoms       0
# Causes         0
# Disease        0
# Medicine       0
# dtype: int64

# %%
unwanted = ['Name', 'DateOfBirth', 'Gender']
df = df.drop(unwanted, axis=1)
df = df.reset_index()
df
# Out:
#      index                    Symptoms                Causes  \
# 0        0                Fever, Cough       Viral Infection
# 1        1           Headache, Fatigue                Stress
# 2        2         Shortness of breath             Pollution
# 3        3            Nausea, Vomiting        Food Poisoning
# 4        4                 Sore Throat   Bacterial Infection
# ..     ...                         ...                   ...
# 236    282  Cough, Shortness of breath  COVID-19 Exposure
# 237    283            Itching, Redness  Allergies
# 238    284        Muscle Pain, Fatigue  Overexertion
# 239    285            Nausea, Vomiting      Food Poisoning
# 240    286    Headache, Blurred Vision  Eye Strain
#
#                   Disease               Medicine
# 0             Common Cold        Ibuprofen, Rest
# 1                Migraine            Sumatriptan
# 2                  Asthma      Albuterol Inhaler
# 3         Gastroenteritis       Oral Rehydration
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     241 non-null    int64
#  1   Symptoms  241 non-null    object
#  2   Causes    241 non-null    object
#  3   Disease   241 non-null    object
#  4   Medicine  241 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 9.5+ KB

# %%
df['Disease'] = df['Disease'].str.upper()
df['Causes'] = df['Causes'].str.upper()
df
# Out:
#      index                    Symptoms                Causes  \
# 0        0                Fever, Cough       VIRAL INFECTION
# 1        1           Headache, Fatigue                STRESS
# 2        2         Shortness of breath             POLLUTION
# 3        3            Nausea, Vomiting        FOOD POISONING
# 4        4                 Sore Throat   BACTERIAL INFECTION
# ..     ...                         ...                   ...
# 236    282  Cough, Shortness of breath  COVID-19 EXPOSURE
# 237    283            Itching, Redness  ALLERGIES
# 238    284        Muscle Pain, Fatigue  OVEREXERTION
# 239    285            Nausea, Vomiting      FOOD POISONING
# 240    286    Headache, Blurred Vision  EYE STRAIN
#
#                   Disease               Medicine
# 0             COMMON COLD        Ibuprofen, Rest
# 1                MIGRAINE            Sumatriptan
# 2                  ASTHMA      Albuterol Inhaler
# 3         GASTROENTERITIS       Oral Rehydration
# ...

# %%
cus = input('Enter The Cause (UPPERCASE): ')

dis_list = df['Disease']
cus_list = df['Causes']

i=0
for value in cus_list:
    if value == cus :
        id = i
        break
    i=i+1

print(id)
# Out:
# Enter The Cause (UPPERCASE): BACTERIAL INFECTION
# 4

# %%
symptomps = df['Symptoms']
medicines = df['Medicine']
disease = df['Disease']

print(f'Symptomps Should Be : {symptomps[id]}\n')
print(f'Detected Disease : {disease[id]}\n')
print(f'Recommended Medicure : {medicines[id]}\n')
# Out:
# Symptomps Should Be : Sore Throat
#
# Detected Disease : STREP THROAT
#
# Recommended Medicure : Penicillin
